# %%
# %cd "/content/drive/MyDrive/workspace/programming-bitcoin"
# Out:
# /content/drive/MyDrive/workspace/programming-bitcoin

# %%
# !git config --global user.email "oooka.takuto@gmail.com"
# !git config --global user.name "TakutoOooka"

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 5 commits.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git add .
# !git commit -m "add ex-bitcoin"
# !git push origin master
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 5 commits.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# error: src refspec master does not match any.
# error: failed to push some refs to 'https://github.com/TakutoOooka/programming-bitcoin.git'

# %%
# !git remote -v
# Out:
# origin	https://github.com/TakutoOooka/programming-bitcoin.git (fetch)
# origin	https://github.com/TakutoOooka/programming-bitcoin.git (push)
